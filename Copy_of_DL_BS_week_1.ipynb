# %% [markdown]
# <a href="https://colab.research.google.com/github/jtneumann/DL-Basketball/blob/master/Copy_of_DL_BS_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
import datetime
index = pd.period_range(start='2017-01-01',end='2020-12-01', freq='M')

# %%
import pandas as pd
data = {'date'}
df1 = pd.DataFrame(columns=data)

# %%
df1.date = index

# %%
df1
# Out:
#        date
# 0   2017-01
# 1   2017-02
# 2   2017-03
# 3   2017-04
# 4   2017-05
# 5   2017-06
# 6   2017-07
# 7   2017-08
# 8   2017-09
# 9   2017-10
# 10  2017-11
# 11  2017-12
# 12  2018-01
# 13  2018-02
# 14  2018-03
# 15  2018-04
# 16  2018-05
# 17  2018-06
# 18  2018-07
# 19  2018-08
# 20  2018-09
# 21  2018-10
# 22  2018-11
# 23  2018-12
# 24  2019-01
# 25  2019-02
# 26  2019-03
# 27  2019-04
# 28  2019-05
# 29  2019-06
# 30  2019-07
# 31  2019-08
# 32  2019-09
# 33  2019-10
# 34  2019-11
# 35  2019-12
# 36  2020-01
# 37  2020-02
# 38  2020-03
# 39  2020-04
# 40  2020-05
# 41  2020-06
# 42  2020-07
# 43  2020-08
# 44  2020-09
# 45  2020-10
# 46  2020-11
# 47  2020-12

# %%
import random
df1['col1'] = random.sample(range(1000000), len(df1))

# %%
df1
# Out:
#        date    col1
# 0   2017-01  800579
# 1   2017-02  925712
# 2   2017-03  656833
# 3   2017-04  911685
# 4   2017-05  107683
# 5   2017-06  416081
# 6   2017-07  490956
# 7   2017-08  895637
# 8   2017-09  129190
# 9   2017-10  630157
# 10  2017-11  235153
# 11  2017-12  652966
# 12  2018-01  126108
# 13  2018-02  556115
# 14  2018-03  454109
# 15  2018-04  273260
# 16  2018-05  101245
# 17  2018-06  679396
# 18  2018-07  517620
# 19  2018-08  537710
# 20  2018-09  419807
# 21  2018-10  592100
# 22  2018-11  436789
# 23  2018-12  570964
# 24  2019-01  720785
# 25  2019-02  713240
# 26  2019-03  355186
# 27  2019-04  544525
# 28  2019-05  337951
# 29  2019-06  216731
# 30  2019-07  991801
# 31  2019-08  444487
# 32  2019-09  807629
# 33  2019-10  632789
# 34  2019-11  718398
# 35  2019-12  656238
# 36  2020-01  477499
# 37  2020-02  441567
# 38  2020-03  764263
# 39  2020-04  238786
# 40  2020-05   69605
# 41  2020-06  502768
# 42  2020-07  355489
# 43  2020-08  708787
# ...

# %%
df1['col2'] = random.sample(range(10000000000), len(df1))

# %%
df1
# Out:
#        date    col1        col2
# 0   2017-01  800579  6190408167
# 1   2017-02  925712  9258410032
# 2   2017-03  656833  6145018883
# 3   2017-04  911685  8392945897
# 4   2017-05  107683   185707031
# 5   2017-06  416081  2766663724
# 6   2017-07  490956  7867198183
# 7   2017-08  895637  9593048003
# 8   2017-09  129190  9444418976
# 9   2017-10  630157  3156184220
# 10  2017-11  235153  7109477466
# 11  2017-12  652966  7183190560
# 12  2018-01  126108  7107876045
# 13  2018-02  556115  3378505455
# 14  2018-03  454109   941455328
# 15  2018-04  273260  9938260647
# 16  2018-05  101245  2808104800
# 17  2018-06  679396  9387672951
# 18  2018-07  517620  8569513289
# 19  2018-08  537710  6646792763
# 20  2018-09  419807   378615035
# 21  2018-10  592100  9542714582
# 22  2018-11  436789  7928012751
# 23  2018-12  570964  7512847025
# 24  2019-01  720785  9635824386
# 25  2019-02  713240  7932697321
# 26  2019-03  355186  4656649073
# 27  2019-04  544525  6151167994
# ...

# %%
df1['col3'] = df1['col2'] - df1['col1']

# %%
df1
# Out:
#        date    col1        col2        col3
# 0   2017-01  800579  6190408167  6189607588
# 1   2017-02  925712  9258410032  9257484320
# 2   2017-03  656833  6145018883  6144362050
# 3   2017-04  911685  8392945897  8392034212
# 4   2017-05  107683   185707031   185599348
# 5   2017-06  416081  2766663724  2766247643
# 6   2017-07  490956  7867198183  7866707227
# 7   2017-08  895637  9593048003  9592152366
# 8   2017-09  129190  9444418976  9444289786
# 9   2017-10  630157  3156184220  3155554063
# 10  2017-11  235153  7109477466  7109242313
# 11  2017-12  652966  7183190560  7182537594
# 12  2018-01  126108  7107876045  7107749937
# 13  2018-02  556115  3378505455  3377949340
# 14  2018-03  454109   941455328   941001219
# 15  2018-04  273260  9938260647  9937987387
# 16  2018-05  101245  2808104800  2808003555
# 17  2018-06  679396  9387672951  9386993555
# 18  2018-07  517620  8569513289  8568995669
# 19  2018-08  537710  6646792763  6646255053
# ...

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
import keras

# %%
keras.__version__
# Out:
# '2.3.1'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def Celsius2Farenheit(CA):
    FA = CA * 9/5 + 32
    return FA

# %%
celsius = np.random.permutation(20)

# %%
celsius
# Out:
# array([ 7, 10,  4, 11,  8, 19,  2, 12, 16,  1, 13, 15, 17,  0, 18,  6, 14,
#         3,  5,  9])

# %%
fahrenheit = Celsius2Farenheit(celsius)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(celsius, fahrenheit, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([16, 19, 15, 11,  5, 14,  0,  4,  1,  9,  8, 17, 12, 13, 18,  2])

# %%
layer0 = tf.keras.layers.Dense(units=1, activation=None, input_shape=[1])

# %%
from tensorflow.keras import layers
model = tf.keras.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
opt = tf.keras.optimizers.SGD(
    learning_rate=0.01, momentum=0.0, nesterov=False, name="SGD"
)

# %%
model.compile(loss='mse', optimizer=opt, metrics=['mean_absolute_error'])

# %%
history = model.fit(X_train, y_train, epochs=60, verbose=True)
print("Training Complete")
# Out:
# Epoch 1/60
# 1/1 [==============================] - 0s 1ms/step - loss: 2656.5771 - mean_absolute_error: 50.3275
# Epoch 2/60
# 1/1 [==============================] - 0s 2ms/step - loss: 2623.4390 - mean_absolute_error: 50.0180
# Epoch 3/60
# 1/1 [==============================] - 0s 1ms/step - loss: 2569.3184 - mean_absolute_error: 49.5036
# Epoch 4/60
# 1/1 [==============================] - 0s 1ms/step - loss: 2568.9277 - mean_absolute_error: 49.4980
# Epoch 5/60
# 1/1 [==============================] - 0s 1ms/step - loss: 2568.6206 - mean_absolute_error: 49.4935
# Epoch 6/60
# 1/1 [==============================] - 0s 1ms/step - loss: 2568.3687 - mean_absolute_error: 49.4898
# Epoch 7/60
# 1/1 [==============================] - 0s 1ms/step - loss: 2568.1548 - mean_absolute_error: 49.4866
# Epoch 8/60
# 1/1 [==============================] - 0s 2ms/step - loss: 2567.9663 - mean_absolute_error: 49.4838
# Epoch 9/60
# ...

# %%
plt.xlabel("Epoch")
plt.ylabel("Loss Amount")
plt.plot(history.history['loss'])

# %%
history1 = model.fit(celsius, fahrenheit, epochs=60, verbose=False)
print("Training Complete")
# Out:
# Training Complete

# %%
plt.figure()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(history1.history['loss'])
plt.show()

# %%
print(model.predict([10.0]))
# Out:
# [[1.]]
